# %% [markdown]
# Members:
# Ma. Kristal Czassandra A. Rivera
# Anwil Shien Oli
# Harold James Enciso
# John Jefferson Catibog
# Kriztoffer Ryan Hernandez
# Joshua Nuevo
# Lanze Ruzzel Orleans
#
# Section: BSCPE Ladderize

# %%
# !git clone https://github.com/AllenDowney/ThinkDSP.git
# Out:
# Cloning into 'ThinkDSP'...
# remote: Enumerating objects: 2733, done.
# remote: Counting objects: 100% (321/321), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 2733 (delta 267), reused 241 (delta 241), pack-reused 2412 (from 1)
# Receiving objects: 100% (2733/2733), 247.12 MiB | 23.48 MiB/s, done.
# Resolving deltas: 100% (1504/1504), done.

# %%
import sys
sys.path.append('/content/ThinkDSP/code')

# %%
import thinkdsp
import matplotlib.pyplot as plt

# %%
signal = thinkdsp.SinSignal(freq=440)
wave = signal.make_wave(duration=0.02, framerate=44100)

# %%
freq = 440
period = 1 / freq

# %%
print("Frequency:", freq, "Hz")
print("Period:", period, "seconds")
# Out:
# Frequency: 440 Hz
# Period: 0.0022727272727272726 seconds

# %%
print("Frequency:", freq, "Hz")
print("Period:", period, "seconds")

for f in [220, 440, 880]:
    signal = thinkdsp.SinSignal(freq=f)
    wave = signal.make_wave(duration=0.01, framerate=44100)

    wave.plot()
    plt.title(f"Frequency = {f} Hz")
    plt.show()
# Out:
# Frequency: 440 Hz
# Period: 0.0022727272727272726 seconds

# %% [markdown]
# ###
# Conclusion
#
# From this activity, I've observed how generating and visualizing sine waves with different frequencies using the `thinkdsp` library clearly shows that as the frequency increases, the number of cycles within the same time duration also increases. It's interesting to see this relationship visually.
